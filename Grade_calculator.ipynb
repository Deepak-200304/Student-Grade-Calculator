# %%
def calculate_grade(marks):
    if 90 <= marks <= 100:
        return "A", "Outstanding performance! Keep shining! "
    elif 80 <= marks <= 89:
        return "B", "Very Good! Keep it up! "
    elif 70 <= marks <= 79:
        return "C", "Good effort! You can do even better! "
    elif 60 <= marks <= 69:
        return "D", "You passed! Keep practicing and improving. "
    else:
        return "F", "Don’t give up! Every failure is a step to success. "

# %%
def get_valid_marks():
    while True:
        try:
            marks = int(input("Enter marks (0-100): "))
            if 0 <= marks <= 100:
                return marks
            else:
                print("Invalid input! Marks must be between 0 and 100.")
        except ValueError:
            print("Please enter a valid number.")

# %%
name = input("Enter Student Name: ")

marks = get_valid_marks()
grade, message = calculate_grade(marks)

print("\n RESULT FOR", name.upper() + ":")
print(f"Marks: {marks}/100")
print(f"Grade: {grade}")
print(f"Message: {message}")
# Out:
# Enter Student Name:  Deepak Tyagi
# Enter marks (0-100):  112
# Invalid input! Marks must be between 0 and 100.
# Enter marks (0-100):  85
#  RESULT FOR DEEPAK TYAGI:
# Marks: 85/100
# Grade: B
# Message: Very Good! Keep it up!
